# %%
# !nvidia-smi
# Out:
# Thu Mar 12 17:04:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %%
# !pwd
# !ls /content
# %cd /content
# !git clone https://github.com/krishnajha23/multiplying.git
# %cd /content/multiplying
# !ls
# !make
# !./matmul
# Out:
# /content
# sample_data
# /content
# Cloning into 'multiplying'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 43 (delta 17), reused 17 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 16.98 KiB | 16.98 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/multiplying
# analysis.cu   benchmark.h	cpu_reference.h  main.cu    utils.cu
# analysis.h    config.h		kernels.cu	 Makefile   utils.h
# benchmark.cu  cpu_reference.cu	kernels.h	 README.md
# nvcc main.cu cpu_reference.cu kernels.cu utils.cu benchmark.cu analysis.cu -lcublas -o matmul
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# Matrix size : 1024 x 1024
# Total FLOPs : 2.15e+09  (2.15 GFLOPs)
#
# CPU:         7040.78 ms  |    0.31 GFLOPS
# ...
